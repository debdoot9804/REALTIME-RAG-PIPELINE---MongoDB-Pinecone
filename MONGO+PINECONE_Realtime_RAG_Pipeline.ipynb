# %% [markdown]
# <a href="https://colab.research.google.com/github/debdoot9804/REALTIME-RAG-PIPELINE---MongoDB-Pinecone/blob/main/MONGO%2BPINECONE_Realtime_RAG_Pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymongo
# !pip install pinecone
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.9/421.9 kB 28.9 MB/s eta 0:00:00
# ...

# %%
# !pip install datasets
# !pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.2/491.2 kB 31.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 12.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 14.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 18.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# ...

# %%
from datasets import load_dataset

# %%
dataset=load_dataset("MongoDB/embedded_movies")
# Out:
# README.md:   0%|          | 0.00/6.17k [00:00<?, ?B/s]
# sample_mflix.embedded_movies.json:   0%|          | 0.00/42.3M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1500 [00:00<?, ? examples/s]

# %%
import pandas as pd
data=pd.DataFrame(dataset['train'])

# %%
data.head()
# Out:
#                                                 plot  runtime  \
# 0  Young Pauline is left a lot of money when her ...    199.0
# 1  A penniless young man tries to save an heiress...     22.0
# 2  Michael "Beau" Geste leaves England in disgrac...    101.0
# 3  Seeking revenge, an athletic young man joins t...     88.0
# 4  An irresponsible young millionaire changes his...     58.0
#
#                        genres  \
# 0                    [Action]
# 1     [Comedy, Short, Action]
# 2  [Action, Adventure, Drama]
# 3         [Adventure, Action]
# 4   [Action, Comedy, Romance]
#
#                                             fullplot  \
# 0  Young Pauline is left a lot of money when her ...
# 1  As a penniless man worries about how he will m...
# 2  Michael "Beau" Geste leaves England in disgrac...
# 3  A nobleman vows to avenge the death of his fat...
# 4  The Uptown Boy, J. Harold Manners (Lloyd) is a...
#
#                               directors  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   plot                1473 non-null   object
#  1   runtime             1485 non-null   float64
#  2   genres              1500 non-null   object
#  3   fullplot            1452 non-null   object
#  4   directors           1487 non-null   object
#  5   writers             1487 non-null   object
#  6   countries           1500 non-null   object
#  7   poster              1411 non-null   object
#  8   languages           1499 non-null   object
#  9   cast                1499 non-null   object
#  10  title               1500 non-null   object
#  11  num_mflix_comments  1500 non-null   int64
#  12  rated               1192 non-null   object
#  13  imdb                1500 non-null   object
#  14  awards              1500 non-null   object
# ...

# %% [markdown]
# #Data Cleaning

# %%
data.isnull().sum()
# Out:
# plot                   27
# runtime                15
# genres                  0
# fullplot               48
# directors              13
# writers                13
# countries               0
# poster                 89
# languages               1
# cast                    1
# title                   0
# num_mflix_comments      0
# rated                 308
# imdb                    0
# awards                  0
# type                    0
# metacritic            928
# plot_embedding         28
# dtype: int64

# %%
df=data.dropna(subset=['fullplot'])

# %%
df.isnull().sum()
# Out:
# plot                    0
# runtime                14
# genres                  0
# fullplot                0
# directors              12
# writers                13
# countries               0
# poster                 78
# languages               1
# cast                    1
# title                   0
# num_mflix_comments      0
# rated                 279
# imdb                    0
# awards                  0
# type                    0
# metacritic            893
# plot_embedding          1
# dtype: int64

# %%
df.drop(columns=['plot_embedding','plot'],inplace=True)
# Out:
# <ipython-input-12-4f789b01d35e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['plot_embedding','plot'],inplace=True)

# %%
df=df.sample(100)
df
# Out:
#       runtime                         genres  \
# 736      92.0    [Action, Adventure, Comedy]
# 1334     84.0      [Action, Crime, Thriller]
# 1364     75.0       [Action, Comedy, Sci-Fi]
# 1380     88.0    [Action, Adventure, Comedy]
# 650      98.0      [Action, Fantasy, Horror]
# ...       ...                            ...
# 1463    107.0       [Action, Drama, Fantasy]
# 1296    114.0     [Action, Adventure, Drama]
# 1352    144.0    [Action, Adventure, Sci-Fi]
# 302      96.0  [Action, Adventure, Thriller]
# 1060    112.0         [Crime, Action, Drama]
#
#                                                fullplot             directors  \
# 736   Baby George got into a plane crash in a jungle...         [Sam Weisman]
# 1334  In the near future, the worst ghettos of Paris...        [Pierre Morel]
# 1364  Orphaned high school student Rick Riker is bit...         [Craig Mazin]
# 1380  The story is about a team of trained secret ag...        [Hoyt Yeatman]
# ...

# %%
# !pip install sentence_transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 115.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 89.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 54.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 16.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 96.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %% [markdown]
# #Embedding model

# %%
from sentence_transformers import SentenceTransformer

embed_model = SentenceTransformer('sentence-transformers/all-MiniLM-L12-v2')
embedding = embed_model.encode("test")
print(embedding.shape)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/352 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# (384,)

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://Debdoot9804:1234@cluster0.jpyhxqg.mongodb.net/?appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %% [markdown]
# #Pushing data to MongoDB Collection, this triggers the MongoDB Listener Client

# %%
db=client["DB_movie"]
collection=db['my_collection']

# %%
document=df.to_dict("Records")

# %%
collection.insert_many(document)
# Out:
# InsertManyResult([ObjectId('67f117b03128e4522feffe1a'), ObjectId('67f117b03128e4522feffe1b'), ObjectId('67f117b03128e4522feffe1c'), ObjectId('67f117b03128e4522feffe1d'), ObjectId('67f117b03128e4522feffe1e'), ObjectId('67f117b03128e4522feffe1f'), ObjectId('67f117b03128e4522feffe20'), ObjectId('67f117b03128e4522feffe21'), ObjectId('67f117b03128e4522feffe22'), ObjectId('67f117b03128e4522feffe23'), ObjectId('67f117b03128e4522feffe24'), ObjectId('67f117b03128e4522feffe25'), ObjectId('67f117b03128e4522feffe26'), ObjectId('67f117b03128e4522feffe27'), ObjectId('67f117b03128e4522feffe28'), ObjectId('67f117b03128e4522feffe29'), ObjectId('67f117b03128e4522feffe2a'), ObjectId('67f117b03128e4522feffe2b'), ObjectId('67f117b03128e4522feffe2c'), ObjectId('67f117b03128e4522feffe2d'), ObjectId('67f117b03128e4522feffe2e'), ObjectId('67f117b03128e4522feffe2f'), ObjectId('67f117b03128e4522feffe30'), ObjectId('67f117b03128e4522feffe31'), ObjectId('67f117b03128e4522feffe32'), ObjectId('67f117b03128e4522fef
# ...

# %%
from google.colab import userdata
PINECONE_API_KEY=userdata.get('PINECONE_API_KEY')
os.environ['PINECONE_API_KEY'] = PINECONE_API_KEY

# %%
from pinecone import Pinecone

pc = Pinecone(api_key=PINECONE_API_KEY)
index = pc.Index("mongo")

# %% [markdown]
# #Retrieval using similarity search

# %%
def get_results(query,k):
  embed_query=embed_model.encode(query)
  embed_query=embed_query.tolist()

  result=index.query(
      vector=embed_query,
      top_k=k,
      #include_values=True
  )
  return result

# %%
query="Suggest good horror movies "

# %%
result=get_results(query,3)
result
# Out:
# {'matches': [{'id': '67f117b03128e4522feffe28',
#               'score': 0.342648327,
#               'values': []},
#              {'id': '67f117b03128e4522feffe6d',
#               'score': 0.301002,
#               'values': []},
#              {'id': '67f117b03128e4522feffe52',
#               'score': 0.288666159,
#               'values': []}],
#  'namespace': '',
#  'usage': {'read_units': 5}}

# %%
from bson.objectid import ObjectId

# %%
mylist=[]
for i in  range(len(result["matches"])):
  value=result["matches"][i]['id']
  mylist.append(collection.find_one({"_id": ObjectId(value)}))

# %%
mylist
# Out:
# [{'_id': ObjectId('67f117b03128e4522feffe28'),
#   'runtime': 115.0,
#   'genres': ['Action', 'Drama', 'Romance'],
#   'fullplot': 'Psycho Joe, a petrol-head from Altona, Melbourne, secures employment at a local Supermarket. Here, he meets the over-sexed Dazey. Joe and Dazey form a friendship based on a mutual interest in old hot cars. Joe also forms a relationship with a Satanic fellow employee. The nihilism of these young characters, coupled with parental disputes, leads to various tragedies.',
#   'directors': ['Geoffrey Wright'],
#   'writers': ['Geoffrey Wright'],
#   'countries': ['Australia'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BN2I5ODAyOTUtOTQzYS00MDdmLWE0YWItZmQwMDM3OGVlZWU0XkEyXkFqcGdeQXVyMTMxMTY0OTQ@._V1_SY1000_SX677_AL_.jpg',
#   'languages': ['English'],
#   'cast': ['Aden Young', 'Tara Morice', 'Nadine Garner', 'Ben Mendelsohn'],
#   'title': 'Metal Skin',
#   'num_mflix_comments': 1,
#   'rated': None,
# ...

# %%
combined_information = ""
for i in range(len(mylist)):
  fullplot=mylist[i]["fullplot"]
  title=mylist[i]["title"]
  combined_information += f"Title:{title}, fullplot: {fullplot}\n"

# %%
print(combined_information)
# Out:
# Title:Metal Skin, fullplot: Psycho Joe, a petrol-head from Altona, Melbourne, secures employment at a local Supermarket. Here, he meets the over-sexed Dazey. Joe and Dazey form a friendship based on a mutual interest in old hot cars. Joe also forms a relationship with a Satanic fellow employee. The nihilism of these young characters, coupled with parental disputes, leads to various tragedies.
# ...

# %%
prompt = f"""Query: {query}\nContinue to answer the query by using the fullplot only:\n{combined_information}."""

# %%
print(prompt)
# Out:
# Query: Suggest good horror movies
# Continue to answer the query by using the fullplot only:
# Title:Metal Skin, fullplot: Psycho Joe, a petrol-head from Altona, Melbourne, secures employment at a local Supermarket. Here, he meets the over-sexed Dazey. Joe and Dazey form a friendship based on a mutual interest in old hot cars. Joe also forms a relationship with a Satanic fellow employee. The nihilism of these young characters, coupled with parental disputes, leads to various tragedies.
# ...

# %%
# !pip install langchain-groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.7/126.7 kB 9.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# #Introducing LLM as last step

# %%
from langchain_groq import ChatGroq

GROQ_API_KEY=userdata.get('GROQ_API_KEY')

# %%
import os
os.environ['GROQ_API_KEY']=GROQ_API_KEY

# %%
llm=ChatGroq(model="gemma2-9b-it")

# %%
Response=llm.invoke(prompt).content
print(Response)
# Out:
# Based on your provided plots, here's a breakdown of which might appeal to a horror fan:
#
# * **Metal Skin:** This one leans towards **psychological horror** with themes of nihilism, tragedy, and possibly demonic influences through the Satanic coworker. The focus on personal struggles and the descent into darkness could be unsettling.
#
# * **Versus:** This screams **creature feature/splatter horror**.  The resurrected dead, the evil spirit, and the description of "gruesome, bloody and positively bold" violence clearly point to a horror movie with lots of action and gore.
#
# * **F/X:** This leans more towards **thriller** with elements of horror. The focus on a staged assassination and the protagonist using special effects to trap people suggests a suspenseful and potentially violent story, but it might not be as overtly scary as the other two.
#
#
# Let me know if you'd like more suggestions, or if you have a specific subgenre of horror in mind!
